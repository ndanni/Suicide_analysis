# %%
#importing tools for anaylysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#to read in the data
suicide_rates = pd.read_csv('..\data\master.csv')
causes_of_deaths = pd.read_csv('..\data/annual-number-of-deaths-by-cause.csv')
causesOfDeathsByPercentage = pd.read_csv('..\data\share-of-deaths-by-cause-2016.csv')

# %%
#a summary of data1
suicide_rates.info()

# %%
#to see the column names of the data
causes_of_deaths.columns

# %%
causesOfDeathsByPercentage.info()

# %%
#dropping columns that are not useful in this analysis
to_drop1 = ['country-year', 'HDI for year', ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation']
data1.drop(columns=to_drop1, inplace=True)

# %%
#to view the first five rows of the data so to know if those columns have been dropped.
data1.head()

# %%
to_drop3 = ['Code']
data3.drop(columns = to_drop3, inplace=True)

# %%
data3.head()

# %%
#to view the minimum and maximum dates of data1
min_year=min(data1.year)
max_year=max(data1.year)
print('Min Year :',min_year)
print('Max Year :',max_year)

# %%
#to view the minimum and maximum dates of data2
min_year=min(data2.Year)
max_year=max(data2.Year)
print('Min Year :',min_year)
print('Max Year :',max_year)

# %%
#to view the minimum and maximum dates of data3
min_year=min(data3.Year)
max_year=max(data3.Year)
print('Min Year :',min_year)
print('Max Year :',max_year)

# %%
#reducing the year in data1 to 1990 in other to have same year values with other data frame.
data1 = data1[data1.year >= 1990]

# %%
#to view the values 'Year'
data1['year'].unique()

# %%
data2['Year'].unique()

# %%
data3['Year'].unique()

# %%
#to know if there are any missing values in the dataset
data1.isnull()

# %%
#to know if there are any missing values in the dataset
data2.isnull()

# %%
#to know if there are any missing values in the dataset
data3.isnull()

# %%
#renaming the column year to Year.
data1.rename(columns={'year':'Year'})
# Out:
#           country  Year     sex          age  suicides_no  population  \
# 36        Albania  1992    male  35-54 years           12      343800
# 37        Albania  1992    male  15-24 years            9      263700
# 38        Albania  1992    male  55-74 years            5      159500
# 39        Albania  1992    male  25-34 years            7      245500
# 40        Albania  1992  female  15-24 years            7      292400
# 41        Albania  1992  female  25-34 years            4      267400
# 42        Albania  1992  female  35-54 years            2      323100
# 43        Albania  1992  female  55-74 years            1      164900
# 44        Albania  1992  female   5-14 years            0      336700
# 45        Albania  1992  female    75+ years            0       38700
# 46        Albania  1992    male   5-14 years            0      362900
# 47        Albania  1992    male    75+ years            0       23900
# 48        Albania  1993    male  15-24 years           18      243300
# 49        Albania  1993    male  55-74 years            7      165000
# 50        Albania  1993    male    75+ years            1       24200
# 51        Albania  1993    male  25-34 years            9      230100
# 52        Albania  1993  female  15-24 years           10      285300
# 53        Albania  1993    male  35-54 years           10      350300
# 54        Albania  1993  female  25-34 years            7      261800
# 55        Albania  1993  female  35-54 years            7      331200
# 56        Albania  1993  female  55-74 years            2      169500
# 57        Albania  1993  female   5-14 years            1      340300
# 58        Albania  1993    male   5-14 years            1      367000
# 59        Albania  1993  female    75+ years            0       39300
# 60        Albania  1994    male    75+ years            2       24600
# 61        Albania  1994    male  55-74 years           11      171400
# 62        Albania  1994  female    75+ years            2       39900
# 63        Albania  1994    male  25-34 years            6      231400
# 64        Albania  1994    male  35-54 years            9      362800
# 65        Albania  1994    male  15-24 years            6      242200
# ...           ...   ...     ...          ...          ...         ...
# 27790  Uzbekistan  2012  female  25-34 years          148     2556673
# 27791  Uzbekistan  2012  female  35-54 years           89     3474788
# 27792  Uzbekistan  2012    male   5-14 years           67     2701361
# 27793  Uzbekistan  2012  female  55-74 years           25     1283060
# 27794  Uzbekistan  2012  female    75+ years            4      338557
# 27795  Uzbekistan  2012  female   5-14 years           16     2578408
# 27796  Uzbekistan  2013    male  35-54 years          481     3346411
# 27797  Uzbekistan  2013    male  25-34 years          328     2644648
# 27798  Uzbekistan  2013  female  15-24 years          323     3039740
# 27799  Uzbekistan  2013    male  15-24 years          320     3171202
# 27800  Uzbekistan  2013    male  55-74 years          119     1202790
# 27801  Uzbekistan  2013    male    75+ years           13      221002
# 27802  Uzbekistan  2013  female  25-34 years          146     2647820
# 27803  Uzbekistan  2013  female  35-54 years           99     3547895
# 27804  Uzbekistan  2013  female    75+ years            8      345180
# 27805  Uzbekistan  2013    male   5-14 years           61     2720938
# 27806  Uzbekistan  2013  female  55-74 years           21     1356298
# 27807  Uzbekistan  2013  female   5-14 years           31     2595000
# 27808  Uzbekistan  2014    male  35-54 years          519     3421300
# 27809  Uzbekistan  2014    male  25-34 years          318     2739150
# 27810  Uzbekistan  2014  female  15-24 years          347     2992817
# 27811  Uzbekistan  2014    male  55-74 years          144     1271111
# 27812  Uzbekistan  2014    male  15-24 years          347     3126905
# 27813  Uzbekistan  2014    male    75+ years           17      224995
# 27814  Uzbekistan  2014  female  25-34 years          162     2735238
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop
# 36                  3.49
# 37                  3.41
# 38                  3.13
# 39                  2.85
# 40                  2.39
# 41                  1.50
# 42                  0.62
# 43                  0.61
# 44                  0.00
# 45                  0.00
# 46                  0.00
# 47                  0.00
# 48                  7.40
# 49                  4.24
# 50                  4.13
# 51                  3.91
# 52                  3.51
# 53                  2.85
# 54                  2.67
# 55                  2.11
# 56                  1.18
# 57                  0.29
# 58                  0.27
# 59                  0.00
# 60                  8.13
# 61                  6.42
# 62                  5.01
# 63                  2.59
# 64                  2.48
# 65                  2.48
# ...                  ...
# 27790               5.79
# 27791               2.56
# 27792               2.48
# 27793               1.95
# 27794               1.18
# 27795               0.62
# 27796              14.37
# 27797              12.40
# 27798              10.63
# 27799              10.09
# 27800               9.89
# 27801               5.88
# 27802               5.51
# 27803               2.79
# 27804               2.32
# 27805               2.24
# 27806               1.55
# 27807               1.19
# 27808              15.17
# 27809              11.61
# 27810              11.59
# 27811              11.33
# 27812              11.10
# 27813               7.56
# 27814               5.92
# 27815               2.96
# 27816               2.58
# 27817               2.17
# 27818               1.67
# 27819               1.46
#
# [24808 rows x 7 columns]

# %%
#groping the data according to country and sexes so as to grasp an undertsanding of the data
data1.groupby(['country', 'sex', 'year', 'age']).suicides_no.sum()
# Out:
# country     sex     year  age
# Albania     female  1987  15-24 years     14
#                           25-34 years      4
#                           35-54 years      6
#                           5-14 years       0
#                           55-74 years      0
#                           75+ years        1
#                     1988  15-24 years      8
#                           25-34 years      5
#                           35-54 years      4
#                           5-14 years       0
#                           55-74 years      3
#                           75+ years        2
#                     1989  15-24 years      5
#                           25-34 years      2
#                           35-54 years      7
#                           5-14 years       0
#                           55-74 years      1
#                           75+ years        0
#                     1992  15-24 years      7
#                           25-34 years      4
#                           35-54 years      2
#                           5-14 years       0
#                           55-74 years      1
#                           75+ years        0
#                     1993  15-24 years     10
#                           25-34 years      7
#                           35-54 years      7
#                           5-14 years       1
#                           55-74 years      2
#                           75+ years        0
#                                         ...
# Uzbekistan  male    2010  15-24 years    246
#                           25-34 years    235
#                           35-54 years    371
#                           5-14 years      48
#                           55-74 years    102
#                           75+ years        9
#                     2011  15-24 years    264
#                           25-34 years    271
#                           35-54 years    457
#                           5-14 years      45
#                           55-74 years     76
#                           75+ years       10
#                     2012  15-24 years    311
#                           25-34 years    290
#                           35-54 years    404
#                           5-14 years      67
#                           55-74 years    133
#                           75+ years       15
#                     2013  15-24 years    320
#                           25-34 years    328
#                           35-54 years    481
#                           5-14 years      61
#                           55-74 years    119
#                           75+ years       13
#                     2014  15-24 years    347
#                           25-34 years    318
#                           35-54 years    519
#                           5-14 years      60
#                           55-74 years    144
#                           75+ years       17
# Name: suicides_no, Length: 27820, dtype: int64

# %%
print((data1[data1['sex'] == 'male']))
# Out:
#           country  year   sex          age  suicides_no  population  \
# 36        Albania  1992  male  35-54 years           12      343800
# 37        Albania  1992  male  15-24 years            9      263700
# 38        Albania  1992  male  55-74 years            5      159500
# 39        Albania  1992  male  25-34 years            7      245500
# 46        Albania  1992  male   5-14 years            0      362900
# 47        Albania  1992  male    75+ years            0       23900
# 48        Albania  1993  male  15-24 years           18      243300
# 49        Albania  1993  male  55-74 years            7      165000
# 50        Albania  1993  male    75+ years            1       24200
# 51        Albania  1993  male  25-34 years            9      230100
# 53        Albania  1993  male  35-54 years           10      350300
# 58        Albania  1993  male   5-14 years            1      367000
# 60        Albania  1994  male    75+ years            2       24600
# 61        Albania  1994  male  55-74 years           11      171400
# 63        Albania  1994  male  25-34 years            6      231400
# 64        Albania  1994  male  35-54 years            9      362800
# 65        Albania  1994  male  15-24 years            6      242200
# 70        Albania  1994  male   5-14 years            1      371800
# 72        Albania  1995  male  25-34 years           13      232900
# 73        Albania  1995  male  55-74 years            9      178000
# 76        Albania  1995  male  15-24 years           11      241200
# 77        Albania  1995  male    75+ years            1       25100
# 78        Albania  1995  male  35-54 years           14      375900
# 81        Albania  1995  male   5-14 years            6      376500
# 84        Albania  1996  male    75+ years            2       25400
# 85        Albania  1996  male  15-24 years           17      243600
# 86        Albania  1996  male  25-34 years           14      235300
# 90        Albania  1996  male  35-54 years           12      379600
# 92        Albania  1996  male  55-74 years            3      179900
# 94        Albania  1996  male   5-14 years            2      380400
# ...           ...   ...   ...          ...          ...         ...
# 27760  Uzbekistan  2010  male  35-54 years          371     3142694
# 27761  Uzbekistan  2010  male  25-34 years          235     2375259
# 27762  Uzbekistan  2010  male  55-74 years          102     1036963
# 27763  Uzbekistan  2010  male  15-24 years          246     3208299
# 27765  Uzbekistan  2010  male    75+ years            9      196160
# 27768  Uzbekistan  2010  male   5-14 years           48     2751752
# 27772  Uzbekistan  2011  male  35-54 years          457     3204569
# 27773  Uzbekistan  2011  male  25-34 years          271     2457050
# 27774  Uzbekistan  2011  male  15-24 years          264     3211080
# 27776  Uzbekistan  2011  male  55-74 years           76     1086405
# 27778  Uzbekistan  2011  male    75+ years           10      204956
# 27780  Uzbekistan  2011  male   5-14 years           45     2710780
# 27784  Uzbekistan  2012  male  35-54 years          404     3273281
# 27785  Uzbekistan  2012  male  55-74 years          133     1141487
# 27786  Uzbekistan  2012  male  25-34 years          290     2548472
# 27788  Uzbekistan  2012  male  15-24 years          311     3199204
# 27789  Uzbekistan  2012  male    75+ years           15      213713
# 27792  Uzbekistan  2012  male   5-14 years           67     2701361
# 27796  Uzbekistan  2013  male  35-54 years          481     3346411
# 27797  Uzbekistan  2013  male  25-34 years          328     2644648
# 27799  Uzbekistan  2013  male  15-24 years          320     3171202
# 27800  Uzbekistan  2013  male  55-74 years          119     1202790
# 27801  Uzbekistan  2013  male    75+ years           13      221002
# 27805  Uzbekistan  2013  male   5-14 years           61     2720938
# 27808  Uzbekistan  2014  male  35-54 years          519     3421300
# 27809  Uzbekistan  2014  male  25-34 years          318     2739150
# 27811  Uzbekistan  2014  male  55-74 years          144     1271111
# 27812  Uzbekistan  2014  male  15-24 years          347     3126905
# 27813  Uzbekistan  2014  male    75+ years           17      224995
# 27817  Uzbekistan  2014  male   5-14 years           60     2762158
#
#        suicides/100k pop
# 36                  3.49
# 37                  3.41
# 38                  3.13
# 39                  2.85
# 46                  0.00
# 47                  0.00
# 48                  7.40
# 49                  4.24
# 50                  4.13
# 51                  3.91
# 53                  2.85
# 58                  0.27
# 60                  8.13
# 61                  6.42
# 63                  2.59
# 64                  2.48
# 65                  2.48
# 70                  0.27
# 72                  5.58
# 73                  5.06
# 76                  4.56
# 77                  3.98
# 78                  3.72
# 81                  1.59
# 84                  7.87
# 85                  6.98
# 86                  5.95
# 90                  3.16
# 92                  1.67
# 94                  0.53
# ...                  ...
# 27760              11.81
# 27761               9.89
# 27762               9.84
# 27763               7.67
# 27765               4.59
# 27768               1.74
# 27772              14.26
# 27773              11.03
# 27774               8.22
# 27776               7.00
# 27778               4.88
# 27780               1.66
# 27784              12.34
# 27785              11.65
# 27786              11.38
# 27788               9.72
# 27789               7.02
# 27792               2.48
# 27796              14.37
# 27797              12.40
# 27799              10.09
# 27800               9.89
# 27801               5.88
# 27805               2.24
# 27808              15.17
# 27809              11.61
# 27811              11.33
# 27812              11.10
# 27813               7.56
# 27817               2.17
#
# [12404 rows x 7 columns]

# %%
#to view the country with the highest suicide rate
plt.figure(figsize=(50,30))
visual = sns.barplot(x = 'country', y = 'suicides_no', data = data1)
visual.set_title('Total rate of suicides between 1990-2016')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'Total rate of suicides between 1990-2016')

# %%
#to view suicide rate by age
plt.figure(figsize=(20,15))
visual2 = sns.barplot(x='age', y='suicides_no', data=data1);
visual2.set_title('Suicide rate by age')
# Out:
# Text(0.5, 1.0, 'Suicide rate by age')

# %%
#to view suicide rate by sex
plt.figure(figsize=(8,10))
figure = sns.barplot(x='sex', y='suicides_no', data=data1);
figure.set_title('Suicide rate by sex')
# Out:
# Text(0.5, 1.0, 'Suicide rate by sex')

# %%
#to view suicde rate by age and sex
plt.figure(figsize=(20,10))
figure2 = sns.barplot(data=data1,x='sex',y='suicides_no',hue='age');
figure2.set_title('suicide rate by sex and age')
# Out:
# Text(0.5, 1.0, 'suicide rate by sex and age')

# %%
#to view suicde rate by age and sex
plt.figure(figsize=(20,10))
figure2 = sns.barplot(data=data2,x='country',y='suicides_no',hue='age');
figure2.set_title('suicide rate by sex and age')

# %%
data2.head()
# Out:
#         Entity Code  Year  Dementia  Cardiovascular diseases  Kidney disease  \
# 0  Afghanistan  AFG  1990     856.0                  28372.0          2708.0
# 1  Afghanistan  AFG  1991     908.0                  30368.0          2851.0
# 2  Afghanistan  AFG  1992     970.0                  33035.0          3057.0
# 3  Afghanistan  AFG  1993    1066.0                  36512.0          3329.0
# 4  Afghanistan  AFG  1994    1161.0                  40285.0          3641.0
#
#    Respiratory disease  Liver disease  Diabetes, blood and endocrine disease  \
# 0               3394.0         1349.0                                 6177.0
# 1               3641.0         1443.0                                 6522.0
# 2               3967.0         1572.0                                 7009.0
# 3               4398.0         1735.0                                 7655.0
# 4               4870.0         1911.0                                 8377.0
#
#    Digestive disease         ...          \
# 0             1708.0         ...
# 1             1792.0         ...
# 2             1911.0         ...
# 3             2071.0         ...
# 4             2243.0         ...
#
#    Heat-related deaths (hot or cold exposure)  Nutritional deficiencies  \
# 0                                       222.0                     567.0
# 1                                       230.0                     588.0
# 2                                       250.0                     623.0
# 3                                       289.0                     674.0
# 4                                       315.0                     731.0
#
#    Suicide  Execution (deaths)  Meningitis (deaths)  \
# 0    703.0                 NaN          4927.029764
# 1    754.0                 NaN          4984.708427
# 2    820.0                 NaN          5135.647154
# 3    894.0                 NaN          5385.702932
# 4    977.0                 NaN          5684.527486
#
#    Lower respiratory infections (deaths)  \
# 0                           17650.382092
# 1                           17775.943869
# 2                           18244.558078
# 3                           19122.639823
# 4                           20221.478296
#
#    Intestinal infectious diseases (deaths)  \
# 0                               295.382207
# 1                               303.866598
# 2                               317.750121
# 3                               333.978331
# 4                               348.419085
#
#    Protein-energy malnutrition (deaths)  Conflict (deaths)  Terrorism (deaths)
# 0                            534.008349             1508.0                12.0
# 1                            552.195285             3498.0                68.0
# 2                            583.667598             4341.0                49.0
# 3                            630.198194                NaN                 NaN
# 4                            681.506962             9090.0                22.0
#
# [5 rows x 36 columns]

# %%
data2.groupby(['Entity','Year'])

# %%
plt.plot(suicides_no, male, data=data1);
plt.plot(suicides_no, female, data=data1);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e6eadc836aa5> in <module>
# ----> 1 plt.plot(suicides_no, male, data=data1);
#       2 plt.plot(suicides_no, female, data=data1);
#
# NameError: name 'suicides_no' is not defined
